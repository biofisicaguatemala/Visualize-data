# %% [markdown]
# ### Phase Plane Interactive Tool

# %% [markdown]
# In this tutorial we will explore the different functionalities of Phase Plane Interactive Tool. Let's begin!

# %%
# !pip install tvb                                 # Our core library
# !pip install matplotlib                          # Basic plotting
# !pip install ipympl                              # This does some plotting magic
get_ipython().kernel.do_shutdown(restart=True)   # Don't ask me why I need to do this
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 kB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 533.0/533.0 kB 14.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 42.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 515.8/515.8 kB 9.0 MB/s eta 0:00:00
# ...
# {'status': 'ok', 'restart': True}

# %%
# %matplotlib widget
from google.colab import output
output.enable_custom_widget_manager()
from tvb.simulator.plot.phase_plane_interactive import PhasePlaneInteractive

# %%
ppi = PhasePlaneInteractive()
# Out:
# /tmp/ipython-input-1496724538.py:1: DeprecationWarning: Call to deprecated class PhasePlaneInteractive. (Use tvb-widgets instead)
#   ppi = PhasePlaneInteractive()

# %%
ppi.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# #### Now let's pass a model and integrator

# %%
import tvb.simulator.models
import tvb.simulator.integrators
ppi2 = PhasePlaneInteractive(model = tvb.simulator.models.JansenRit())
# Out:
# /tmp/ipython-input-1074103102.py:3: DeprecationWarning: Call to deprecated class PhasePlaneInteractive. (Use tvb-widgets instead)
#   ppi2 = PhasePlaneInteractive(model = tvb.simulator.models.JansenRit())

# %%
#ppi2.plot_phase_plane()
ppi2.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
